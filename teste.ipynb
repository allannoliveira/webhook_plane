# %%
curl -X POST http://localhost:5000/webhooks/plane?token="f7A9$2xP!Qm8" \
  -H "Content-Type: application/json" \
  -d '{"event":"test","data":{}}'
# Out:
#   Cell In[2], line 1
#     curl -X POST http://localhost:5000/webhooks/plane?token="f7A9$2xP!Qm8" \
#             ^
# SyntaxError: invalid syntax
